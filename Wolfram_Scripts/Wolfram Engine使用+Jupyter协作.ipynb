# %% [markdown]
# # https://zhuanlan.zhihu.com/p/115381177

# %%
Table[RandomColor[],10]
# Out:
# {RGBColor[0.8611, 0.536981, 0.530504], RGBColor[0.822846, 0.274549, 0.318144],
#
# >   RGBColor[0.160767, 0.959554, 0.0262666], RGBColor[0.732209, 0.916094, 0.986043],
#
# >   RGBColor[0.611548, 0.191825, 0.0776715], RGBColor[0.421716, 0.288127, 0.0834545],
#
# >   RGBColor[0.819995, 0.649291, 0.987123], RGBColor[0.376323, 0.625018, 0.570439],
#
# >   RGBColor[0.657935, 0.778775, 0.202918], RGBColor[0.742849, 0.0811713, 0.829252]}

# %% [markdown]
# # Integrate[x^5+6x+2,{x,-3,2}]

# %%
Plot3D[Sin[x*y],{x,-Pi,Pi},{y,-Pi,Pi}]
# Out:
# -Graphics3D-

# %%
Graph[Table[i -> Mod[i^2, 74], {i, 100}]]
# Out:
# Graph[<101>, <100>]

# %%
heqn = {Laplacian[u[x, y], {x, y}] + 5 u[x, y] == 0};

# %%
bc = {u[x, 0] == UnitTriangle[x - 2]/2, u[x, 2] == 0, u[0, y] == 0, 
   u[4, y] == 0};

# %%
(sol = DSolveValue[{heqn, bc}, u[x, y], {x, y}]) // TraditionalForm
# Out:
# FormBox[TemplateBox[List[FractionBox[RowBox[List["32", " ",
#
#
# >           RowBox[List[SuperscriptBox["sin", "3"], "(",
#
#
# >             RowBox[List[FractionBox["1", "8"], " ", "\[Pi]", " ",
#
#
# >               RowBox[List["K", "[", "1", "]"]]]], ")"]], " ",
#
#
# >           RowBox[List["(", RowBox[List[RowBox[List["cos", "(",
#
#
# >                 RowBox[List[FractionBox["1", "8"], " ", "\[Pi]", " ",
#
#
# >                   RowBox[List["K", "[", "1", "]"]]]], ")"]], "+",
#
#
# >               RowBox[List["cos", "(",
#
#
# >                 RowBox[List[FractionBox["3", "8"], " ", "\[Pi]", " ",
#
#
# >                   RowBox[List["K", "[", "1", "]"]]]], ")"]]]], ")"]], " ",
#
#
# >           RowBox[List["csch", "(", RowBox[List[FractionBox["1", "2"], " ",
#
#
# >               SqrtBox[RowBox[List[RowBox[List[SuperscriptBox["\[Pi]", "2"], " ",
#
#
# >                    SuperscriptBox[RowBox[List["K", "[", "1", "]"]], "2"]]], "-",
#
#
# >                  "80"]]]]], ")"]], " ",
#
#
# >           RowBox[List["sin", "(", RowBox[List[FractionBox["1", "4"], " ", "\[Pi]",
#
#
# >               " ", "x", " ", RowBox[List["K", "[", "1", "]"]]]], ")"]], " ",
#
#
# >           RowBox[List["sinh", "(", RowBox[List[FractionBox["1", "4"], " ",
#
#
# >               RowBox[List["(", RowBox[List["2", "-", "y"]], ")"]], " ",
#
#
# >               SqrtBox[RowBox[List[RowBox[List[SuperscriptBox["\[Pi]", "2"], " ",
#
#
# >                    SuperscriptBox[RowBox[List["K", "[", "1", "]"]], "2"]]], "-",
#
#
# >                  "80"]]]]], ")"]]]],
#
#
# >         RowBox[List[SuperscriptBox["\[Pi]", "2"], " ",
#
#
# >           SuperscriptBox[RowBox[List["K", "[", "1", "]"]], "2"]]]],
#
#
# >        RowBox[List["K", "[", "1", "]"]], "1", "\[Infinity]"], "InactiveSum",
#
#
# >       Rule[DisplayFunction, Function[RowBox[List[UnderoverscriptBox[StyleBox["\
#
#
# >   \[Sum]", "InactiveTraditional"], RowBox[List[Slot[2], "=", Slot[3]]], Slot[4]],
#
#
# >           Slot[1]]]]], Rule[InterpretationFunction,
#
#
# >        Function[RowBox[List[RowBox[List["Inactive", "[", "Sum", "]"]], "[",
#
#
# >           RowBox[List[Slot[1], ",", RowBox[List["{",
#
#
# >               RowBox[List[Slot[2], ",", Slot[3], ",", Slot[4]]], "}"]]]], "]"]]]],
#
#
# >       Rule[SyntaxForm, Sum]], TraditionalForm]

# %%
fsol = sol /. \[Infinity] -> 30 // Activate;

# %%
Plot3D[fsol // Evaluate, {x, 0, 4}, {y, 0, 2}, PlotRange -> All, 
 PlotTheme -> "Scientific"]
# Out:
# -Graphics3D-
